# %%
# !pip install qwen-vl-utils[decord]==0.0.8
# Out:
# Requirement already satisfied: qwen-vl-utils==0.0.8 in ./miniconda3/lib/python3.12/site-packages (from qwen-vl-utils[decord]==0.0.8) (0.0.8)
# Requirement already satisfied: av in ./miniconda3/lib/python3.12/site-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (14.2.0)
# Requirement already satisfied: packaging in ./miniconda3/lib/python3.12/site-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (23.2)
# Requirement already satisfied: pillow in ./miniconda3/lib/python3.12/site-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (10.4.0)
# Requirement already satisfied: requests in ./miniconda3/lib/python3.12/site-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (2.32.3)
# Requirement already satisfied: decord in ./miniconda3/lib/python3.12/site-packages (from qwen-vl-utils[decord]==0.0.8) (0.6.0)
# Requirement already satisfied: numpy>=1.14.0 in ./miniconda3/lib/python3.12/site-packages (from decord->qwen-vl-utils[decord]==0.0.8) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./miniconda3/lib/python3.12/site-packages (from requests->qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/lib/python3.12/site-packages (from requests->qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./miniconda3/lib/python3.12/site-packages (from requests->qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/lib/python3.12/site-packages (from requests->qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (2024.6.2)

# %%
# !pip install -U git+https://github.com/huggingface/transformers
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-_88pyu1k
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-_88pyu1k
#   Resolved https://github.com/huggingface/transformers to commit 858545047c05a35fde437b2ada3a901844cd1e60
# done
# done
# done
# Requirement already satisfied: filelock in ./miniconda3/lib/python3.12/site-packages (from transformers==4.50.0.dev0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in ./miniconda3/lib/python3.12/site-packages (from transformers==4.50.0.dev0) (0.26.0)
# Requirement already satisfied: numpy>=1.17 in ./miniconda3/lib/python3.12/site-packages (from transformers==4.50.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in ./miniconda3/lib/python3.12/site-packages (from transformers==4.50.0.dev0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in ./miniconda3/lib/python3.12/site-packages (from transformers==4.50.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in ./miniconda3/lib/python3.12/site-packages (from transformers==4.50.0.dev0) (2024.9.11)
# Requirement already satisfied: requests in ./miniconda3/lib/python3.12/site-packages (from transformers==4.50.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./miniconda3/lib/python3.12/site-packages (from transformers==4.50.0.dev0) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in ./miniconda3/lib/python3.12/site-packages (from transformers==4.50.0.dev0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in ./miniconda3/lib/python3.12/site-packages (from transformers==4.50.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.0.dev0) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./miniconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.0.dev0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./miniconda3/lib/python3.12/site-packages (from requests->transformers==4.50.0.dev0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/lib/python3.12/site-packages (from requests->transformers==4.50.0.dev0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./miniconda3/lib/python3.12/site-packages (from requests->transformers==4.50.0.dev0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/lib/python3.12/site-packages (from requests->transformers==4.50.0.dev0) (2024.6.2)

# %%
import torch
torch.cuda.empty_cache()

# %%
# !pip install qwen-vl-utils==0.0.10
# Out:
# Requirement already satisfied: qwen-vl-utils==0.0.10 in ./miniconda3/lib/python3.12/site-packages (0.0.10)
# Requirement already satisfied: av in ./miniconda3/lib/python3.12/site-packages (from qwen-vl-utils==0.0.10) (14.2.0)
# Requirement already satisfied: packaging in ./miniconda3/lib/python3.12/site-packages (from qwen-vl-utils==0.0.10) (23.2)
# Requirement already satisfied: pillow in ./miniconda3/lib/python3.12/site-packages (from qwen-vl-utils==0.0.10) (10.4.0)
# Requirement already satisfied: requests in ./miniconda3/lib/python3.12/site-packages (from qwen-vl-utils==0.0.10) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./miniconda3/lib/python3.12/site-packages (from requests->qwen-vl-utils==0.0.10) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./miniconda3/lib/python3.12/site-packages (from requests->qwen-vl-utils==0.0.10) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./miniconda3/lib/python3.12/site-packages (from requests->qwen-vl-utils==0.0.10) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./miniconda3/lib/python3.12/site-packages (from requests->qwen-vl-utils==0.0.10) (2024.6.2)

# %% [markdown]
# # ***Video Explanation***

# %%
from transformers import Qwen2_5_VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from qwen_vl_utils import process_vision_info
model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    "Qwen/Qwen2.5-VL-7B-Instruct", torch_dtype="auto", device_map="auto"
)

processor = AutoProcessor.from_pretrained("Qwen/Qwen2.5-VL-7B-Instruct")
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "video",
                "video": "/home/avidmech/file_example_MP4_480_1_5MG.mp4",
                "max_pixels": 128 * 128,
                "fps": 1.0,
            },
            {"type": "text", "text": "Describe this video."},
        ],
    }
]


text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)
image_inputs, video_inputs, video_kwargs = process_vision_info(messages, return_video_kwargs=True)
inputs = processor(
    text=[text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
    **video_kwargs,
)
inputs = inputs.to("cuda")

# Inference
generated_ids = model.generate(**inputs, max_new_tokens=256)
generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
output_text = processor.batch_decode(
    generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
)
print(output_text)
# Out:
# 2025-03-10 14:59:28.091683: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-10 14:59:28.116009: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# qwen-vl-utils using decord to read video.
# ["The video shows a rotating Earth against a black background. The planet is illuminated, highlighting the continents and oceans. The lighting suggests it is nighttime on parts of the Earth, with city lights visible in certain regions, indicating human habitation. The rotation is smooth and continuous, giving a realistic depiction of the Earth's movement. The overall scene captures the beauty and vastness of our planet from space."]

# %% [markdown]
# # ***Image Comparison***

# %%
from transformers import Qwen2_5_VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from qwen_vl_utils import process_vision_info
model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    "Qwen/Qwen2.5-VL-7B-Instruct", torch_dtype="auto", device_map="auto"
)

processor = AutoProcessor.from_pretrained("Qwen/Qwen2.5-VL-7B-Instruct")
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image", "image": "/home/avidmech/2cats.jpg"},
            {"type": "image", "image": "/home/avidmech/images.jpeg"},
            {"type": "text", "text": "Identify the similarities between these images and describe the similarity in great details."},
        ],
    }
]

# Preparation for inference
text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)
inputs = inputs.to("cuda")

# Inference
generated_ids = model.generate(**inputs, max_new_tokens=256)
generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
output_text = processor.batch_decode(
    generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
)
print(output_text)
# Out:
# 2025-03-10 14:40:34.853945: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-10 14:40:34.878093: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# ["The two images both feature pairs of kittens, and they share several similarities:\n\n1. **Subject Matter**: Both images prominently display kittens as their main subjects. The kittens appear to be young and playful.\n\n2. **Setting**: The background in both images is plain white, which isolates the kittens and draws attention to them without any distractions. This type of setting is often used in pet photography to emphasize the subject.\n\n3. **Pose and Interaction**: In both images, the kittens are positioned close to each other, suggesting a sense of companionship or playfulness. They seem to be interacting gently with one another, either standing side by side or slightly overlapping.\n\n4. **Lighting**: The lighting in both images appears soft and even, highlighting the kittens' fur textures and facial features without creating harsh shadows. This type of lighting is typical for pet photography to enhance the subjects' appearance.\n\n5. **Fur Color**: While the kittens in the first image have distinct fur colors (one orange and one white), the second image shows kittens with gray fur. Despite the difference in color, the texture and sheen of their fur are similar, indicating that they might belong to the same breed or have similar coat types.\n\n6. **Focus on the Kittens**: Both images focus"]

# %% [markdown]
# # ***Image Desription Generation***

# %%
from transformers import Qwen2_5_VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from qwen_vl_utils import process_vision_info

# default: Load the model on the available device(s)
model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    "Qwen/Qwen2.5-VL-7B-Instruct", torch_dtype="auto", device_map="auto"
)

# We recommend enabling flash_attention_2 for better acceleration and memory saving, especially in multi-image and video scenarios.
# model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
#     "Qwen/Qwen2.5-VL-7B-Instruct",
#     torch_dtype=torch.bfloat16,
#     attn_implementation="flash_attention_2",
#     device_map="auto",
# )

# default processer
processor = AutoProcessor.from_pretrained("Qwen/Qwen2.5-VL-7B-Instruct")

# The default range for the number of visual tokens per image in the model is 4-16384.
# You can set min_pixels and max_pixels according to your needs, such as a token range of 256-1280, to balance performance and cost.
# min_pixels = 256*28*28
# max_pixels = 1280*28*28
# processor = AutoProcessor.from_pretrained("Qwen/Qwen2.5-VL-7B-Instruct", min_pixels=min_pixels, max_pixels=max_pixels)

messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
                "image": "/home/avidmech/images.jpeg",
            },
            {"type": "text", "text": "Describe this image."},
        ],
    }
]

# Preparation for inference
text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)
inputs = inputs.to("cuda")

# Inference: Generation of the output
generated_ids = model.generate(**inputs, max_new_tokens=256)
generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
output_text = processor.batch_decode(
    generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
)
print(output_text)
# Out:
# 2025-03-10 14:43:31.335440: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-10 14:43:31.359393: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# ['The image shows two kittens with gray fur and white markings on their faces, chests, and paws. They appear to be of the same breed, possibly a domestic shorthair, given their short fur and similar physical features. The kitten in the foreground is slightly larger and has its head turned towards the camera, while the smaller kitten behind it is looking to the side. Both kittens have large, expressive eyes and are standing close together against a plain white background.']
